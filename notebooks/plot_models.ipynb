# %%
# %load_ext autoreload
# %autoreload 2

# %%
from globalVariables import *
import simpleCNNwithInception as inceptionCNN
import simpleCNN as simpleCNN
import simpleCNNwithInceptionRegression as regressor
from keras.callbacks import CSVLogger
from scipy.ndimage import rotate
from tools import plot_confusion_matrix
from getSIDMdata_generator import get_tf_DataSet as getGenerators

# %%
train, test = getGenerators(augment_data=True, simulationNames=['CDM','SIDM0.1','SIDM1'], 
                                                      channels=['total','stellar'], 
                                                      allDataFile='pickles/binned_data_20.pkl')
# Out:
# /Users/davidharvey/Work/darkCNN/lib/python3.10/site-packages/keras/preprocessing/image.py:766: UserWarning: NumpyArrayIterator is set to use the data format convention "channels_last" (channels on axis 3), i.e. expected either 1, 3, or 4 channels on axis 3. However, it was passed an array with shape (2880, 100, 100, 2) (2 channels).
#   warnings.warn(
# 90/90 [==============================] - 9s 98ms/step - loss: 0.9663 - accuracy: 0.5042 - val_loss: 0.8531 - val_accuracy: 0.5764

# %%
inputLayer = tf.keras.layers.InputLayer(test[1].shape[1:])
mainCNN = layers.Conv2D(16, 3, padding='same', activation='relu')
mainCNN =       layers.MaxPooling2D()(mainCNN)
mainCNN =      layers.Conv2D(32, 3, padding='same', activation='relu')(mainCNN)
mainCNN =      layers.MaxPooling2D()(mainCNN)
mainCNN =       layers.Conv2D(64, 3, padding='same', activation='relu')(mainCNN)
mainCNN =      layers.MaxPooling2D()(mainCNN)
mainCNN =      layers.Flatten()(mainCNN)
mainCNN = layers.Dense(128, activation='relu')(mainCNN)
mainCNN =        layers.Dense(nClasses)(mainCNN)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 mainCNN = tf.keras.layers.InputLayer(test[1].shape[1:])
# ----> 2 mainCNN = layers.Conv2D(16, 3, padding='same', activation='relu')(mainCNN)
#       3 mainCNN =       layers.MaxPooling2D()(mainCNN)
#       4 mainCNN =      layers.Conv2D(32, 3, padding='same', activation='relu')(mainCNN)
#
# File ~/Work/darkCNN/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
fiducial_model. = test[1].shape[1:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Work/darkCNN/lib/python3.10/site-packages/keras/engine/base_layer.py:3112, in Layer.__setattr__(self, name, value)
#    3111 try:
# -> 3112     super(tf.__internal__.tracking.AutoTrackable, self).__setattr__(
#    3113         name, value
#    3114     )
#    3115 except AttributeError:
#
# AttributeError: can't set attribute 'input_shape'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fiducial_model.input_shape = test[1].shape[1:]
#
# File ~/Work/darkCNN/lib/python3.10/site-packages/keras/engine/training.py:361, in Model.__setattr__(self, name, value)
#     354     except AttributeError:
#     355         raise RuntimeError(
# ...

# %%
tf.keras.utils.plot_model(fiducial_model, show_shapes=False,expand_nested=True, show_layer_activations=False)
